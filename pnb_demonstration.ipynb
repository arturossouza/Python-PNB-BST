# %%
from phd.classes.trabalho_final.pnb_bst.Pnb_Bst import Pnb_Bst
import numpy as np

# %%
num_of_leafs = 10

# %%
pnb_tree = Pnb_Bst()

# %%
for i in range(num_of_leafs):
    pnb_tree.insert(np.random.randint(0, 50))

# %%
pnb_tree.visualize()

# %%
pnb_tree.search(10), pnb_tree.search(36).key
# Out:
# (None, 36)

# %%
pnb_tree.delete(10)

# %%
pnb_tree.visualize()

# %%
pnb_tree.delete(36)
pnb_tree.visualize()

# %%
pnb_tree.find_key_range(1, 10)
# Out:
# [8]

# %%
pnb_tree.find_key_range(1, 30)
# Out:
# [24, 8, 25, 29, 30]

# %%
pnb_tree.visualize_versions()
